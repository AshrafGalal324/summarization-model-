# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
from matplotlib import rc
import joblib

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
from torch import nn,optim
from torch.utils.data import Dataset, DataLoader
from torchmetrics.functional import f1
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger

from sklearn.model_selection import train_test_split

from tqdm.auto import tqdm

# %%
m=6000
text=[]
summary=[]
df=pd.read_csv('/kaggle/input/arabic-text-summarization-30-000/wikiHow.csv')
for i in range(df.shape[0]):
    if len(df['text'][i])< m:
        text.append(df['text'][i])
        summary.append(df['summary'][i])
        
df = pd.DataFrame({'text': text, 'summary': summary})
df['summary'] = df['summary'].replace(r'\n', '', regex = True)
df.head()
# Out:
#                                                 text  \
# 0  الأطعمة الصحية ليست باهظة الثمن بالضرورة، بل ف...
# 1  استفد من حديقتك المنزلية أو أصيص الزرع الصغير ...
# 2  تساعدك الخطط المسبقة في كل نواحي حياتك على وضع...
# 3  نظرا لأن السبب الرئيسي لضغط العين هو أن ثقافة ...
# 4  افعل ذلك وأنت جالس لمنع نفسك من النوم. أغلق عي...
#
#                                              summary
# 0  فضل خيارات الأطعمة الأرخص ثمنا. تباطأ في استهل...
# 1  ازرع كل ما يمكنك من خضراوات وفاكهة. اطه بنفسك ...
# 2  خطط مسبقا لوجباتك الرئيسية لمدة أسبوع. التزم ب...
# 3           قلل وقت التعرض للشاشات. اذهب إلى الطبيب.
# 4                                        أغلق عينيك.

# %%
train, val = train_test_split(df, test_size=0.1, random_state=42)

train.to_csv("train.csv",index=False)
val.to_csv("val.csv",index=False)

# %%
class SummaryDataset(Dataset):
    def __init__(
        self,
        data,
        text_max_token_len = 2000,
        summary_max_token_len = 150
    ):
        self.tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
        self.data = data
        self.text_max_token_len = text_max_token_len
        self.summary_max_token_len = summary_max_token_len
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        data_row = self.data.iloc[index]

        text = data_row['text']

        text_encoding = self.tokenizer(
            text,
            max_length=self.text_max_token_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            add_special_tokens=True,
            return_tensors='pt'
        )

        summary_encoding = self.tokenizer(
            data_row['summary'],
            max_length=self.summary_max_token_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            add_special_tokens=True,
            return_tensors='pt'
        )
        
        labels = summary_encoding['input_ids']
        labels[labels == self.tokenizer.pad_token_id] = -100
        
        return dict(
            input_ids=text_encoding['input_ids'].flatten(),
            attention_mask=text_encoding['attention_mask'].flatten(),
            labels=labels.flatten(),
            decoder_attention_mask=summary_encoding['attention_mask'].flatten()
        )

# %%
class SummaryDataModule(pl.LightningDataModule):
    def __init__(self,train_path,val_path,batch_size=12, text_max_token_len = 2000, summary_max_token_len = 150):
        super().__init__()
        self.train_path,self.val_path= train_path,val_path
        self.batch_size = batch_size
        self.text_max_token_len = text_max_token_len
        self.summary_max_token_len = summary_max_token_len
    
    def setup(self,stage=None):
        train = pd.read_csv(self.train_path)
        val = pd.read_csv(self.val_path)
        self.train_dataset = SummaryDataset(data=train,
                                            text_max_token_len=self.text_max_token_len,
                                            summary_max_token_len=self.summary_max_token_len)
        self.val_dataset = SummaryDataset(data=val,
                                          text_max_token_len=self.text_max_token_len,
                                          summary_max_token_len=self.summary_max_token_len)
    
    def train_dataloader(self):
        return DataLoader(self.train_dataset, shuffle=True, num_workers=4)

    def val_dataloader(self):
        return DataLoader(self.val_dataset, shuffle=False, num_workers=4)

# %%
class T5SumModel(pl.LightningModule):
    def __init__(self, lr=0.0001):
        super().__init__()
        self.lr = lr
        self.model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
    
    def forward(self, input_ids, attention_mask, decoder_attention_mask, labels=None):
        output = self.model(
            input_ids,
            attention_mask=attention_mask,
            labels=labels,
            decoder_attention_mask=decoder_attention_mask
        )
        return output.loss, output.logits
    
    def configure_optimizers(self):
        return optim.AdamW(self.parameters(), lr=self.lr)
    
    def training_step(self, batch, batch_size):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        decoder_attention_mask = batch['decoder_attention_mask']

        loss, outputs = self(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels
        )

        self.log("train_loss", loss, prog_bar=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_size):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        decoder_attention_mask = batch['decoder_attention_mask']

        loss, outputs = self(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels
        )

        self.log("val_loss", loss, prog_bar=True, logger=True)
        return loss

# %%
dm = SummaryDataModule(train_path="./train.csv",
                val_path = "./val.csv",
                text_max_token_len = 1000, #largest length kaggle's GPUs can handle
                batch_size=1)

# First Time only
trained_model = T5SumModel() 


# Traing
trainer = pl.Trainer(gpus=-1, max_epochs=2, default_root_dir='.', callbacks=[EarlyStopping(monitor="val_loss")])
trainer.fit(trained_model,dm)
# Out:
# Downloading:   0%|          | 0.00/730 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
# Save the model
checkpoint_path = "/kaggle/working/checkpoint.ckpt"
trained_model.model.save_pretrained(checkpoint_path)

# %%
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")



def summarizeText(text, mymodel):
    text_encoding = tokenizer(
        text,
        max_length=1000,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    )
    generated_ids = mymodel.generate(
        input_ids=text_encoding['input_ids'],
        attention_mask=text_encoding['attention_mask'],
        max_length=150,
        num_beams=2,
        repetition_penalty=2.5,
        length_penalty=1.0,
        early_stopping=True
    )

    preds = [
            tokenizer.decode(gen_id, skip_special_tokens=True, clean_up_tokenization_spaces=True)
            for gen_id in generated_ids
    ]
    return "".join(preds)

# %%
test = val.sample(10)
for i in range(len(test)):
    sample_row = test.iloc[i]
    text = sample_row['text']
    print('Text : ', text)
    print('\n')
    print('Summary (Ground truth) : ',sample_row['summary'])
    print('\n')
    summary_without_tuning = summarizeText(text, model)
    print("Summary before tuning", summary_without_tuning)
    print('\n')
    summary_with_tuning = summarizeText(text, trained_model.model)
    print("Summary after tuning", summary_with_tuning)
    print('\n')
    print('-------------------------------------------------------------------------------------------------')
# Out:
# Text :  لو اعتقدت أنك تعرف دور صديقك، فمن الممكن أن يصيبك الإحباط وخيبة الأمل. قد يكون صديقك المقرب واحدا من أكثر الأشخاص قيمة في حياتك، لكنه لن يساعدك ويدعمك في كل جوانب حياتك. فلا تتوقع أن يتواجد دوما من أجلك وأن يسمعك ما ترغب في سماعه. ستصيبك التوقعات العالية جدا لدور صديقك في حياتك بالإحباط والشعور بالخيبة.  كن مسؤولا عن نفسك. أنت صديق نفسك المفضل، وأنت المسؤول عن رعاية ذاتك. إذا كنت كذلك، فلن تضع صديقك في موقف يجعله يسرع للتدخل وإنقاذك. وإن حدث هذا، فلن تخيب آمالك يوما. تذكر أنه ما من شخص كامل، حتى صديقك المفضل. لكل شخص منا أخطائه، التي يحتاج المساعدة لإصلاحها. لا تتصرف بحدة تجاه صديقك بسبب أخطائه، بل ساعده على إصلاحها، واطلب منه مساعدتك على إصلاح أخطائك أيضا. ومع ذلك عليك الحذر حين تخبر صديقك عن خطأ فعله، حتى لا تؤذي مشاعره، ومن الأفضل أن تركز فقط على الأخطاء الكبيرة التي تشكل تهديدا على صداقتكما. وميز الأخطاء التي يمكن تجاهلها والأخرى التي يتعين عليك مساعدة صديقك لإصلاحها. في بعض الأحيان قد تحتاج إلى ترك صديقك ليصلح خطئه دون مساعدتك -إلا إذا طلب منك ذلك-. أما التذمر المستمر، فسيشعر صديقك بالتوتر والغضب، وقد يصبح غير راغب في تحسين صداقتكما إذا استمريت في الضغط عليه. من الطبيعي أن تتوقف عن التناغم مع شخص بعينه. لو حدث وابتعدتما لأي سبب كان، فكن ممتنا لأوقاتكما السعيدة، واعلم كم كنت محظوظا لأن شخصا رائعا مثله كان جزءا من حياتك يوما.  إن لم يبذل أي منكما جهدا لتكونا معا، أو كثرت شجاراتكما دون أي سبب، فربما لم يكن مقدرا لكما أن تكونا صديقين مقربين. وهذا ليس خطأ أي منكما. فربما أنتما متشابهان أكثر من اللازم، من يعلم! وربما تحتاجان فقط لأخذ استراحة من بعضكما لعدة أسابيع. عامل صديقك باحترام دوما، حتى لو ابتعدتما. لا تغضب منه، فالأمر لا يستحق أن تحمل غضبا داخلك. كن مهذبا ولطيفا ومحترما إذا انهارت صداقتكما. فأنت لن تعرف متى ستتغير الأشياء. لو فضل صديقك صديقا آخر عليك، فحاول أن تصادق صديقه هذا، فربما تصبحون مجموعة أصدقاء معا. الكل يبحث دوما عن أصدقاء جدد، ولكن إياك أن تتخلى عن القدامى، فهم ينتظرون منك الولاء لهم ويعتمدون على ذلك كل يوم.
#
#
# Summary (Ground truth) :  تجنب أي توقعات. تقبل حقيقة أن حتى الأصدقاء الجيدون يضطرون للابتعاد عن بعضهم أحيانا. دع صديقك يحصل على أصدقاء غيرك.
#
#
# Summary before tuning يمكن أن تكون أصدقاء جدد في حياتك، ولكن إذا كنت متمسكين بصديقك المقرب، فإنك لن تتوقف عن التناغم مع الآخرين.
#
#
# Summary after tuning كن على دراية بأمور صديقك. اطلب المساعدة. توقف عن التناغم. كن محترما.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  لإيجاد محيط مثلث أضلاعه هي أ و ب و ج فإننا نرمز لكلمة محيط بالرمز م فتكتب هكذا: م = أ + ب + ج. ما تعنيه هذه الصيغة بشكل مبسط أنه لإيجاد محيط المثلث عليك أن تحسب طول كل ضلع من أضلاعه الثلاثة وتجمعهم معا. في هذا المثال: طول الضلع أ=5 وطول الضلع ب= 5 وأيضا طول الضلع ج= 5.  في هذا المثال يسمي المثلث مثلثا متساوي الأضلاع لأن أضلاعه الثلاثة متساوية الطول، لكن تذكر أن هذه الصيغة لحساب المحيط لا تختلف مهما اختلف نوع المثلث. في المثال السابق نجد أن 5 + 5 + 5 = 15، إذا م = 15. إذا استخدمت مثالا آخر وكان أ = 4 و ب = 3 و ج = 5 فإن إيجاد المحيط سيكون كالتالي: م = 3 + 4 + 5 أو 12. إن كانت وحدة قياس أطوال أضلاع المثلث هي السنتيمتر، فينبغي لإجابتك أن تكون بالسنتيمتر. أما إن كانت وحدة قياس الأطوال مختلفة، مثل المتر، فإن إجابتك وقتها يجب أن تأخذ تمييزا بالوحدة متر. إذا افترضنا كما في المثال السابق أن طول كل ضلع من الأضلاع 5 سم، حينها تكون القيمة الصحيحة للمحيط هي 15 سم.
#
#
# Summary (Ground truth) :  تذكر هذه الصيغة لإيجاد محيط المثلث. انظر إلى مثلثك واحسب أطوال الأضلاع الثلاثة. اجمع أطوال الأضلاع الثلاثة معا ثم أوجد المحيط. تذكر أن تكتب الوحدات المستخدمة في الإجابة النهائية.
#
#
# Summary before tuning هل يمكنك أن تحسب طول كل ضلع من أضلاع المثلث بشكل متساوي الأضلاع؟
#
#
# Summary after tuning اكتب رمز محيط المثلث. احسب طول كل ضلع من الأضلاع.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  اختار العديد من أصحاب الشعر المجعد أو شديد التجعيد الانتقال من طريقة الغسل بالشامبو إلى طريقة غسل الشعر بالبلسم. توصل هؤلاء إلى أن غسل الشعر بالبلسم يعطي نفس نتيجة الشامبو في تنظيف الشعر دون أن يجففه. يساعد البلسم على ترطيب التجعيدات والحفاظ على شكلها بدلا من إفسادها وفردها.  ابحثي عن بلسم خالي من السيليكون. ما يفعله السيليكون هو أنه يغطي شعرك بطبقة لامعة في بداية الأمر، ثم يبدأ في التراكم على خصلات شعرك ويعطي تجعيداتك طلة باهتة وغير محددة. إذا أردت أن تستخدمي الشامبو، احصلي على شامبو خالي من الكبريت. الكبريت عبارة عن عامل تنظيف يجرد الشعر من ترطيبه ويلحق الضرر بالشعر المجعد. يساعد ذلك على غلق الطبقة الخارجية لشعرك للحفاظ على رطوبته حتى بعد أن يجف.ادهني أصابعك بزيت أو زبدة التصفيف ومرري أصابعك في شعرك خصلة تلو الأخرى حتى تظل التجعيدات متماسكة. تعد أنواع الزيت والزبدة التالية خيارات شائعة:  زيت الأرجان زبدة الشيا زبدة الكاكاو الكريمات التي تحتوي على أحد المكونات السابقة سيروم تعزيز التجعيدات عادة ما تجفف مستحضرات التصفيف الشعر وتسبب تطايره. اختبري رذاذ الشعر والجل ومستحضرات التصفيف الأخرى على خصلة صغيرة من شعرك قبل الاستخدام للتعرف على النتائج قبل تغطيه شعرك بالكامل بها.
#
#
# Summary (Ground truth) :  حاولي أن تغسلي شعرك بالبلسم بدلا من الشامبو. استخدمي زيت أو زبدة التصفيف. تجنبي المستحضرات التي تجفف الشعر.
#
#
# Summary before tuning هناك بعض الحيل التي تمكن منها أصحاب الشعر المجعد والشديد التجعيد.
#
#
# Summary after tuning اغسلي شعرك بالبلسم. استخدمي زيت أو زبدة التصفيف.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  يوجد العديد من الحالات التي قد يطلب منك بسببها كتابة تقارير سير العمل، لكن يظل الغرض العام من هذا النوع من التقارير هو أن تشرح مدى التقدم الذي حققته في خطة عملك على مشروع معين. خلاف ذلك، يوجد تفصيلات إضافية تميز الأنواع المختلفة لمحتوى تقارير سير العمل التي تقدمها للجهة المعنية. ضع في اعتبارك ما يلي:  تكون تقارير سير العمل الخاصة بالبرامج البحثية أو المشاريع الدراسية مختلفة نوعا ما إذا قارنتها بتقارير سير العمل في المشاريع المهنية التي تقدمها في وظيفتك في مؤسسة أو شركة. في حالة البرامج البحثية، ستحتاج إلى توثيق المعلومات ومصادرها على حساب بعض الجوانب الأخرى، مثل التكلفة والمصاريف المالية (عادة وليس دائما). يختلف التقرير الموجه إلى العميل عن ذلك الموجه إلى المشرف أو المدير في العمل. يجب عليك أن تضع في اعتبارك لمن تكتب التقرير ولماذا. عند تحليلك للغرض من كتابتك لتقرير سير العمل، يجب أن تضع في الاعتبار الأنواع المختلفة للبنود والعناصر التي يحتاج القارئ المتوقع للتقرير لإيجادها في المحتوى الذي تقدمه. يوجد إطار عام ثابت نسبيا في كل تقارير سير العمل، لكن يظل من الضروري أن تنتبه بالتفصيل إلى المحددات التالية:   ما هي علاقة القارئ بالمشروع الذي تعمل عليه؟ كيف تؤثر نتائج المشروع النهائية عليهم؟ (على سبيل المثال: تختلف علاقة مديرك في العمل عن العميل بالمشروع الذي تعمل عليه، وكذلك شكل تأثرهم بالنتائج النهائية للمشروع، وهو ما يؤثر كليا على شكل محتوى التقرير وطريقة صياغته). فكر في القرارات التي يحتاج القارئ إلى القيام بها بعد الاطلاع على التقرير الذي تقدمه إليه (نوعية الدعم أو الأموال أو الوقت الذي يفترض بهم استثماره لدعم إتمام المشروع، على سبيل المثال) فكر في المعلومات التي يجب أن يتعرف عليها القارئ ليقدر على الإلمام بجوانب العمل على المشروع، ومن ثم المشاركة بإيجابية والتأثير على دعمه في المرحلة المقبلة؛ ما هي الجوانب التقنية التي يجب أن يتعرف عليها القارئ (بصفته، سواء كان زميل عمل أو مشرف أو عميل)؟ ما مدى إلمام القارئ المتوقع بالمصطلحات العلمية؟ من الشائع اعتقاد أن تقرير سير العمل يتم كتابته وتوجيهه فقط إلى المدير في العمل أو الأستاذ الجامعي المشرف على رسالة علمية، بل على خلاف ذلك يوجد عدد كبير من أنواع تقارير سير العمل التي تختلف بناء على سياق تقديمها ونوعية الاحتياج لها.   يمكن أن يتم عرض تقرير سير العمل بشكل شفوي مختصر أسبوعيا أو شهريا في اجتماعات فرق العمل. يمكن أن يكون على شكل رسائل بريد إلكتروني دورية لزملاء العمل أو الدراسة. يمكن أن يكون على شكل مذكرات (رسائل قصيرة) رسمية أو غير رسمية موجهة للمشرفين. يمكن أن يكون كذلك على شكل تقرير رسمي للعملاء أو الجهات الحكومية. قد تحتاج إلى بعض النصائح والتوجيهات لإعداد التقرير، خاصة إذا لم يسبق لك كتابة هذا النوع من التقارير من قبل (لهذا السبب أنت تقرأ هذا المقال على الأغلب)! اطلب المشورة من مديرك المباشر أو المشرف المعني بمراقبة مهامك في الدعم وتقديم الدعم والنصيحة. يوجد العديد من الصيغ والأشكال التي قد يتم استخدامها في الشركة أو المنظمة التي تعمل بها، وسيكون عليك وقتها أن تراعي بكل حرص التزامك بالقواعد والتعليمات الخاصة بتلك التوجيهات. لا يتم كتابة كل تقارير متابعة سير العمل بلغة رسمية، بل على العكس، عادة ما تكون التقارير الداخلية (داخل إطار الشركة أو المنظمة) بين الزملاء والموظفين والمشرفين أكثر ميلا للأسلوب غير الرسمي. بناء على ما سبق، تحتاج إلى التواصل مع مديرك المباشر لمعرفة نوعية وأسلوب صياغة التقرير المنتظر منك أن تقدمه.   بالحديث عن تقديم المعلومات إلى الجهات الحكومية أو عملاء الشركة أو عند تقديمك أطروحتك العلمية لمجلس الجامعة، كن أكثر ميلا لكتابة تقرير سير عمل بلغة رسمية وقورة. بعيدا عما يخص الصياغة اللغوية الرسمية أو غير الرسمية، يجب أن تكون صياغتك في أي حالة من الاثنين ملتزمة بالوضوح والتركيز والأمانة.
#
#
# Summary (Ground truth) :  تعرف على الغرض من التقرير. تعرف على الجمهور المستهدف. حدد الطريقة الأمثل للتواصل مع الجمهور المتوقع. راجع التقرير مع المدير المباشر. اختر نبرة الكتابة المناسبة.
#
#
# Summary before tuning يمكن أن تكتب تقارير سير العمل الخاصة بالبرامج البحثية أو المشاريع الدراسية التي تقدمها في وظيفتك، لكن هل ترغب في التوصل إلى أدلة على ذلك؟
#
#
# Summary after tuning ضع في اعتبارك نوعية التقارير التي تقدمها. اكتب تقرير سير العمل.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  يمكن أن يكون هذا شخصا أو شركة.  اكتب أي ألقاب ضرورية. يمكنك تخطي الألقاب مع الأصدقاء المقربين وأفراد العائلة ولكن قد ترغب في إضافة الألقاب مع مسؤولي الحكومة والموظفين العسكريين والأطباء والأساتذة وكبار السن. هذا مهم خاصة في المناطق الريفية التي بها المنازل أو الممتلكات معروفة بالاسم بدلا من العنوان. مثلا يمكنك كتابة " شارع الموسكي 3". مثلا "1234 القليوبية". إذا كنت ترسل الخطاب من خارج المحافظة فاكتبه على السطر الأخير.
#
#
# Summary (Ground truth) :  اكتب اسم مستلم الخطاب على السطر الأول. اكتب اسم المنزل على السطر الثاني (لو أمكن). اكتب اسم الشارع ورقمه على السطر الثالث. اكتب الرقم البريدي والمدينة واختصار المحافظة (لو أمكن) على السطر الرابع. اكتب المحافظة على السطر الخامس (لو أمكن). النهاية.
#
#
# Summary before tuning يمكنك كتابة خطاب ضروري في المحافظة؟
#
#
# Summary after tuning اكتب الخطاب على السطر الأخير. أدخل اسم الشخص الذي ترغب في إضافته إليه. انقر بزر الفأرة الأيمن لكتابة خطابك.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  لا تحاول أبدا تسوية الأمر مع المتطفل. يجب أن تتجنب التواصل معه قدر الإمكان. لكن قد تجبر أحيانا على التعامل مع المتطفل، خاصة إذا كان صديق سابق أو شريكتك السابقة على سبيل المثال. ستساعدك الخطوات التالية في حالة إذا لم يكن هنالك مفر من التحدث مع الشخص المتطفل، لكن يجب أن تحافظ على تعاملك معه في إطار محدد وبشكل مختصر قدر الإمكان. لا تحاول إصلاح الأمر مع المتطفل ولا تعتقد أنك ستتمكن من فعل ذلك. يعتبر الحل الوحيد هو قطع الاتصال نهائيا بذلك الشخص. قل ببساطة أنك لم تعد ترغب في صداقته بعد الآن. أبق جملك مختصرة وبسيطة، ثم أنه المكالمة أو غادر المكان. لا تضع شروطا مثل: "يمكننا أن نتقابل مجددا إذا..." أو اقتراح مثل: "سيصلح الوقت كل شيء بيننا." لا تترك فرصة لمضايقات مستقبلية.  يمكنك استخدام بعض الجمل مثل: "لا أرغب في رؤيتك مجددا، هل هذا واضح؟" "لم نعد أنا وأنت معا بعد الآن. ستضطر للرحيل الآن نهائيا." "لقد انتهت علاقتنا ببعضنا البعض تماما." قل للمتطفل بكلمات مختصرة قدر الإمكان ألا يتواصل معك نهائيا. يمكنك قول "لا تحاول الاتصال بي مجددا." لا تدخل في حوار أو مناقشة طويلة أو حتى قائمة من الاعتذارات. أخبره أنك ستبلغ الشرطة عن اعتدائه بك إذا حاول الاقتراب منك مرة أخرى. يعتبر هدفك هو إخبار المتطفل أن تصرفاته تضايقك، وكذلك أنك تحذره من الاقتراب والتواصل معك مرة أخرى. وثق طريقة تحذيرك له وكذلك تاريخها، بالإضافة إلى أي اعتداءات مستقبلية إن وجدت. لا تستمع إلى وجهة نظره في الأمر مهما توسل إليك. فهو يبعد تمام البعد عن نقطة إعطائه فرصة للتبرير. قد يحاول ذلك المتطفل مضايقتك عبر قول وكتابة الكثير من التعليقات والرسائل المستفزة. إذا قمت بالرد، حتى وإن كان ردا سلبيا، فسيغذي ذلك ثقته وقناعته بأنه سينجح في التواصل معك. كن قويا واستمر في ما تفعله، وارفض الاستماع لأي رسالة صوتية يرسلها لك. لا يهم مدى الوقاحة والوضاعة التي قد يصل لها ذلك المتطفل، لا تعره انتباهك فقط. لا تحاول إصلاح الأمور أو الانتقام أو شرح وجهة نظرك. لن ترغب في التواصل معه بأي شكل، سواء كان بشكل إيجابي أو سلبي أو محايد. ما يجب عليك قوله فقط هو: "أتركني وشأني قبل أن أبلغ الشرطة." قد يوفر هؤلاء الأشخاص بعض المعلومات عنك لذلك المتطفل، سواء كان عن عمد أو بدون قصد، مثل أن يخبروه بعنوانك الجديد أو رقم هاتفك. لا تسمح لأي شخص أن يحاول الإصلاح بينكما كمحاولة للتواصل معك. لتتخلص من المتطفل نهائيا فعليك قطع جميع سبل الاتصال بينكما.
#
#
# Summary (Ground truth) :  تجنب التحدث مع المتطفل الذي يتتبعك إلا إذا كان الأمر ضروريا. صرح عن رغبتك في تجنب ذلك المتطفل تماما دون أي تفاصيل. حذر المتطفل أو المعتدي من العواقب الواضحة لأفعاله. تجاهل جميع محاولاته للتواصل معك. تجنب التواصل مع أصدقاء المتطفل وأقربائه ومعارفه.
#
#
# Summary before tuning يمكن أن تتخلص من المتطفل الآخر، الذي حاول التواصل معه بشكل مختصر قدر الإمكان، إذا لم تكن ترغب في صداقتك.
#
#
# Summary after tuning تجنب التواصل مع المتطفل. اقطع اتصالك بذلك الشخص.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  تستمر أنواع الخس مثل الأيس برغ والروماني وأنواع الخس الأخرى ذات اللب الصلب لفترة أطول عند إزالة اللب. اقطعي اللب بالسكين أو اضربي الساق على لوح التقطيع بشدة ثم لفيه لإزالة اللب بيدك. لا تزيلي الساق من خس البترهيد أو أي خس بأوراق فضفاضة وطرية. لفي رأس الخس أو الأوراق الفضفاضة في طبقة واحدة بين قطعتين من مناشف ورقية ناعمة وماصة؛ سوف يعمل ذلك على امتصاص المياه الزائدة مع إبقاء الخس في الظروف الرطبة التي يفضلها.  إذا كان الخس يبدو جافا، بللي المناشف الورقية.  إذا كان الخس رطبا بقدر كاف لغمر المناشف الورقية، اعصري الماء الزائد ولفي الخس في نفس المناشف الرطبة مرة أخرى. إذا كان الخس يأتي في كيس من الأوراق الفضفاضة، جففيه في مصفاة السلطة الدوارة. يمكن أن يكون ذلك كيسا قابل للغلق بسحاب أو وعاء من البلاستيك المتماسك أو حتى مصفاة السلطة الدوارة. إذا كنت تستخدمين كيسا، أخرجي بعض الهواء قبل غلقه بدون كبس الأوراق. إذا كنت تستخدمين وعاء بلاستيكيا، املأيه بالأوراق إلى النصف. كلما تركت هواء في الوعاء ستتحول حواف الأوراق إلى اللون البني بشكل أسرع. إذا فرغت كل الهواء وأغلقت الوعاء تماما، قد لا ينشأ الخس نكهة بسبب فقر التنفس. قد يكون ترك القليل من الهواء أو كسر الوعاء قليلا فكرة جيدة، خاصة مع ورق الخس أو في ثلاجة في الجانب الدافئ. يعد ذلك أبرد جزء من الثلاجة والذي يعتبر مثاليا للخضروات الورقية. ينبغي أن يستمر الخس المباع في البقالة لمدة 3 إلى 7 يوم هنا بناء على نضارته بينما قد يستمر خس الأيسبرغ لمدة تصل إلى أسبوعين. يمكن أن يستمر الخس الطازج المحصود من حديقتك أو من مزرعة لفترة أطول.  لا تكدسي الأوراق في مساحات ضيقة مع الأطعمة الأخرى والتي قد تسبب تكدمها. لا تخزنيه في نفس الدرج مع التفاح والكمثرى والطماطم والتي تنتج كميات كبيرة من غاز الإيثيلين الذي يسبب فساده. إذا كانت المياه تتدفق من جوانب الوعاء، اخفضي إعداد رطوبة الثلاجة أو افتحي فتحات التهوية بدرجة أوسع في درج الخضروات وقد تحتاجين أيضا إلى تصريف المياه الزائدة. إذا رأيت ثلجا في درج الخضروات أو على الأوراق، ارفعي حرارة الثلاجة.
#
#
# Summary (Ground truth) :  أزيلي لب الخس من رأس الخس. لفي الخس في مناشف ورقية. خزنيه في وعاء بلاستيك. ضع الخس في درج الخضروات. راقبي الوعاء.
#
#
# Summary before tuning قد يكون الخس طازج المحصود من حديقتك أو من مزرعة في ثلاجة، ولكن إذا كنت تستخدمه أيضا، فإنك لا تحتاج إلى ذلك.
#
#
# Summary after tuning أزيلي اللب الصلب من الساق. جففي الخس في مصفاة السلطة الدوارة. اتركي الهواء يبرد لمدة 3 إلى 7 يوم.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  اقلبي القميص على ظهره بحيث يمكنك رؤية البقعة. خذي قطعة أخرى من القميص وافركي بها موضع البقعة. بدلي بين استخدام الحركات الدائرية والحركة صعودا وهبوطا. تأكدي من استخدام الوجه الداخلي من القميص لفرك البقعة، وذلك احترازا في حال أن انتقلت البقعة إلى الجزء النظيف أيضا. احرصي على تجفيف البقعة أولا قبل فركها بورق تجفيف. إذا لم يمكنك إيجاد ورق التجفيف، فجربي استخدام زوج من الجوارب النايلون بدلا من ذلك. افركي البقعة في حركة دائرية وصعودا وهبوطا. يمكنك أيضا استخدام أحد الجوارب لإزالة البقعة. اقلبي الجورب من الداخل وافركي البقعة به حتى تختفي. ضعي قطعة قماش (مثل منشفة أو قطعة قماش نظيفة) في الماء الساخن وأضيفي بضع قطرات من الصابون. دلكي قطعة القماش حتي يصل الصابون إلى الألياف ثم افركيها فوق البقعة. يجب أن تختفي البقعة في غضون دقائق قليلة. إذا كان هناك بواقي للصابون على القميص، ضعي قطعة القماش في ماء نظيف وافركي بها موضع البقعة حتى يختفي الصابون. إذا لم يكن بإمكانك استخدام الماء لأي سبب من الأسباب، فجربي استخدام المناديل المبللة أو مناديل إزالة المكياج. اشتري إسفنجة التنظيف السحرية من قسم التنظيف في محل البقالة أو السوق. بللي الإسفنجة واعصري المياه الزائدة. افركي البقعة بالإسفنجة في حركة صعودا وهبوطا. املئي الحوض بالماء وأضيفي معيار مزيل البقع المحدد على الملصق. ضعي القميص في الحوض واتركيه ينقع. لإزالة البقع الخفيفة، اتركي القميص في الماء لمدة ساعة. لإزالة البقع الأعمق، اتركي القميص منقوعا طوال الليل أو طوال النهار. بمجرد الانتهاء من نقع القميص، اغسليه في غسالة الملابس بالطريقة المعتادة. يمكنك أيضا تجربة استخدام قلم مزيل للبقع أو بخاخ. يمكن شراء كلاهما من قسم المنظفات في متجر البقالة. اخلطي القليل من صودا الخبز مع ما يكفي من الماء لصنع عجينة. افركي المعجون على البقعة واتركيه لمدة ساعة. اغسلي المعجون باستخدام الماء البارد ثم اغسلي القميص في غسالة الملابس. اخلطي مقدارا من الخل الأبيض مع مقدار مساو من الماء. انقعي البقعة في هذا المحلول وافركيها بأصابعك. إذا كانت البقعة شديدة، انقعي القميص في المحلول لبضع ساعات. بمجرد الانتهاء اغسلي القميص في غسالة الملابس.
#
#
# Summary (Ground truth) :  افركي موضع البقعة بجزء آخر من القميص. افركي البقعة بورق التجفيف أو زوج من الجوارب النايلون. نظفي البقعة بقطعة قماش مبللة بالصابون. أزيلي البقعة باستخدام ممحاة التنظيف السحرية. استخدمي مزيل البقع. نظفي البقعة باستخدام معجون صودا الخبز والماء. اغسلي البقعة بالخل والماء.
#
#
# Summary before tuning يمكنك أن تستخدم قميصا منقوعا في متجر بقالة أو سوق للملابس بطريقة غير مسبوقة. إذا لم يكن هناك بواقي للصابون عليه، فإن الطريقة قد تكون صعبة.
#
#
# Summary after tuning استخدمي القميص لإزالة البقعة. اصنعي عجينة من الصابون.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  ربما تمتلك مشاعر قوية لذلك الشخص، ولكن أحيانا لا يكون الشخصان متوافقين. إن كانت العلاقة ضارة فعليك المضي قدما بدلا من محاولة استعادة شريكك السابق. إليك بعض العلامات على فشل العلاقة وعدم قابليتها للإصلاح:   إساءة المعاملة بأي شكل. إن آذاك شريكك السابق بأي شكل أو أجبرك على ممارسة الجنس أو فعل أشياء غير مريحة لك فهو مسيء للمعاملة وعليك تجنب استعادته.  نقص الاحترام من أي الجانبين. إن قمتما بسباب بعضكما أو التهوين من إنجازاتكما أو تحقير بعضكما أو أصدقائكما أو عائلتيكما فإن العلاقة تفتقر للاحترام. تلك جميعها سمات للعلاقة المسيئة عاطفيا. ابحث عن شخص يظهر لك الاحترام الذي تستحقه والتزم بمعاملته باحترام كذلك. سابقة خيانة. رغم أن بعض العلاقات تستمر بعد الخيانة فإن الثقة المكسورة يصعب إصلاحها، وحتى إن أمكنكما بناؤها فإن كسرها يكون سهلا. تحتاج العلاقة التي مرت بحالة خيانة إلى دعم إضافي على هيئة علاج زواجي مستمر لإصلاح الثقة المدمرة. قد تشعر بالدفاعية، ولكن أولئك الأقرب إليك وعلى معرفة وطيدة بك سيمتلكون بصيرة جيدة للعلاقة. إن أخبرك شخص موثوق بأن لديه شعورا سيئا حيال علاقتكما فعليك اعتبار ذلك مؤشرا على وجود مشكلة محتملة.  إن كنت تعرف أن صديقا أو فردا من العائلة لا يحب شريكك السابق فناقشه في السبب. اعرف ما إن كان ذلك مبنيا على طريقة معاملة شريكك السابق لك أو للآخرين، أو على معرفة لدى صديقك لا تملكها، أو أي دليل آخر ذي مغزى. إن لم تنجح أي من الطرق السابقة، وقمت أنت أو شريكك بتقييم المشكلة وقررت أنه من غير الصحي أو الحكيم الاستمرار في محاولة استعادة شريكك السابق فتأكد من أخذ وقت كاف لنفسك عاطفيا للتعافي من انفطار القلب.   طبقا للأبحاث فإنه من المهم أن تركز على أفضل جوانب العلاقة، خصوصا كيفية مساعدتها لك في التطور كشخص، وأن تدع نفسك تنسى التجارب السلبية. أحد الاستراتيجيات التي تساعدك في فعل هذا هي قضاء 15 إلى 30 دقيقة يوميا لمدة ثلاثة أيام متتالية في الكتابة عن الجوانب الإيجابية للانفصال.  حاول نسيان العلاقة بعد قضاء تلك الأيام الثلاثة. امنح نفسك وقتا للبقاء وحدك أو مع الأصدقاء والعائلة وفعل ما تحبه. عندما تكون في حالة صحية فيمكنك البدء بالبحث عن الحب ثانية.
#
#
# Summary (Ground truth) :  انتبه لعلامات فشل العلاقة الحتمي. أنصت لأصدقائك وأفراد عائلتك. اقبل الانفصال وامض قدما.
#
#
# Summary before tuning هل تشعر بأن لديه شعورا سيئا حيال علاقتك؟
#
#
# Summary after tuning تعرف على علامات فشل العلاقة. اعرف ما إن كان شريكك السابق يشعر بالدفاعية. خذ وقتك للتعافي من انفطار القلب.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  إذا كنت تكتب لفرض مدرسي، تأكد من معرفة طول المقال المطلوب والإلمام بأي معايير متعلقة بموضوع المقال. سيساعدك هذا في تحديد كم المعلومات المطلوب جمعها وتقديمها جيدا. راجع جيدا رأس الموضوع المطلوب أو مخطط الفرض أولا. إذ ما زلت في حاجة لمزيد من التوضيح، اسأل مدرسك.  احرص على فهم الكيفية التي يريد معلمك اختيار مصادرك بها حتى تتمكن من متابعة بحثك على نهج سليم. توفر بعض المدارس بعض البرامج مثل "EndNote" أو "RefWorks"  التي قد تسهل جمع مصادر البحث وتتبعها. انتبه للمتطلبات التنسيقية. عادة ما ينص الفرض على بعض التعليمات مثل إذا كان المقال مطلوبا بخط اليد أم مطبوعا، وما نوع الخط المطلوب استخدامه وحجمه. إذا لم يكن منصوصا نوع الخط وحجمه، فان الاختيار الآمن هو استخدام الخط "Arila" أو "Times New Roman" حجم "12" المعياري الواضح. تجنب استخدام أي خطوط مبهرجة أو غير احترافية إلا إذا وجد تصريح استثنائي لذلك. اعلم موعد التسليم. ابدأ باكرا حتى يتسنى لك وفرة من الوقت لكتابة المقال. ستحتاج إلى اختيار موضوعك إذا لم يكن قد حدد لك بالفعل عنوان بعينه. من السهل أن تعلق حائرا عند هذه الخطوة إذا كان هناك العديد من الخيارات المتاحة أمامك، لذلك خذ وقتك واتبع بعض القواعد العامة.  لا ينبغي أن يكون الموضوع كبير للغاية أو بسيط للغاية. اقرأ مقال كيفية كتابة مقالة لمزيد من المعلومات. يجب أن يحوي الموضوع من المعلومات ما يكفي للكتابة عنه، ولكن ليس كما هائلا يصعب تقديمه بشكل واضح ومركز. على سبيل المثال، يعد موضوع مثل "تاريخ ملاجئ الحيوانات في العالم" واسع جدا ، وموضوع مثل "تاريخ ملجأ إيسما للحيوانات في مصر" محدود جدا. الأفضل أن تختار موضوعا وسطا مثل: "تاريخ ملاجئ الحيوانات الانتقائية في أوروبا". ينبغي أن يكون الموضوع مناسبا وجذابا لقرائك. فكر مقدما في الفئة المعنية لقراءة مقالك. بالطبع إذا كان مقالك فرض مدرسي، فسيكون معلمك هو هدفك الأساسي، ولكن عامة ينبغي أن تحدد جمهور قرائك دائما. ما الذي يريدون معرفته؟ وما الذي يقدمه مقالك من معلومات جديدة لهؤلاء القراء؟ في وضع مثالي، ينبغي أن يكون الموضوع مثيرا لاهتمامك أنت. هكذا ستكون عملية الكتابة أسهل بكثير، ويمكنك نقل حماسك لقارئك. هذا الجزء مهم خاصة للمقال الإخباري، حيث يجب أن تذكر معلومات دقيقة. احرص جيدا على استخدام مصادر معلومات موضوعية مكتوبة على يد خبراء متخصصين في موضوعك. يمكن أن يساعدك أمين المكتبة في إيجاد مصادر معلومات موثوقة مثل الموسوعات أو الكتب أو المقالات أو المواقع الإلكترونية المتعلقة. كن حذرا عند استخدام الإنترنت، وهذا يشمل مواقع مثل ويكيبيديا حيث يحوي الكثير من المعلومات غير الموثوقة. لأفضل النتائج، ابحث عن مصادر عبر الإنترنت تابعة لوكالات حكومية أو جامعات أو مؤسسات ذات سمعة جيدة. يعد موقع جوجل سكولار "google scholar" مكانا جيدا للبدء. ضع جانبك ورقة فارغة أو مذكرة لتسجل فيها الحقائق الشيقة التي تجدها، ويمكن أيضا أن تسجل ملاحظات على جهاز الكمبيوتر. أيا كان ما ستختار، احرص فقط على أن تجمع كل ملاحظاتك في مكان واحد. لكتابة مقال إخباري: ستحتاج إلى كتابة مقدمة وثلاث أفكار رئيسة على الأقل وخاتمة. من الممكن أن تقسم ورقة ملاحظاتك إلى تلك الأقسام الثلاث، وتبدأ بتدوين الأفكار في القسم الذي ترى أنها تنتمي إليه. ينبغي أن تعرف مقدما ما هي المعلومات التي ستحتاجها عند ذكر مصادرك. ينبغي عادة ذكر المؤلف وعنوان المصدر والناشر وحقوق النشر وعنوان الموقع الإلكتروني (إن كان له صلة بالمصدر). عندما تشعر أنك قد جمعت ما يكفي من المعلومات، سيساعدك استيضاحها في رؤية الروابط بينها وتقسيمها في مجموعات مترابطة.  ارسم خارطة أفكار. ضع عنوان موضوعك في منتصف ورقة، ثم اكتب أهم المعلومات أو الأفكار المتعلقة بالموضوع في دوائر حول العنوان، وارسم خطوطا تصل كل فكرة بالعنوان الرئيسي. أضف بعد ذلك التفاصيل الخاصة بكل فكرة في دوائر حولها، ثم صلها بتلك الفكرة لتوضح العلاقة. يمكن أيضا أن توصل خطوطا بين الأفكار وبعضها أو بين التفاصيل وبعضها. اصنع قائمة. إذا كنت تفضل التنسيق الطولي للقائمة، يمكنك كتابة عنوانك الرئيسي أولا، ثم اكتب تحته الأفكار والمعلومات التي جمعتها، وتحت كل فكرة التفاصيل الإضافية التي تدعمها. لا تشغل نفسك الآن بوضع تلك الأفكار في ترتيب معين، فستأتي هذه الخطوة لاحقا.  اكتب بشكل حر. ستساعدك الكتابة الحرة على توليد الأفكار، حتى وإن كانت لا تمثل شكلا نهائيا منقحا يمكنك تقديمه للقراءة. حدد لنفسك مدة زمنية قصيرة ولتكن ربع ساعة، ثم ابدأ في الكتابة عن موضوعك بلا توقف للتعديل أو تصحيح الإملاء. استمر في الكتابة حتى وإن لم تكن متأكدا من أن لديك ما تقوله فعلا، المهم أن تكتب لمدة خمسة عشر دقيقة.
#
#
# Summary (Ground truth) :  افهم فرضك جيدا. حدد موضوعك. قم ببحثك جيدا. سجل الملاحظات أثناء البحث. تعقب مصادرك. تمعن واستوضح الأفكار التي جمعتها.
#
#
# Summary before tuning يمكن أن تساعدك في قراءة المقال المطلوب.
#
#
# Summary after tuning اعرف طول الموضوع المطلوب. اختر موضوعا مناسبا لقرائك. قم بجمع ملاحظاتك في مكان واحد.
#
#
# -------------------------------------------------------------------------------------------------
