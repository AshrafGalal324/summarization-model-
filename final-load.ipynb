# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
from matplotlib import rc
import joblib

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
from torch import nn,optim
from torch.utils.data import Dataset, DataLoader

import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger

from sklearn.model_selection import train_test_split

from tqdm.auto import tqdm

# %%
class SummaryDataset(Dataset):
    def __init__(
        self,
        data,
        text_max_token_len = 2000,
        summary_max_token_len = 150
    ):
        self.tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
        self.data = data
        self.text_max_token_len = text_max_token_len
        self.summary_max_token_len = summary_max_token_len
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        data_row = self.data.iloc[index]

        text = data_row['text']

        text_encoding = self.tokenizer(
            text,
            max_length=self.text_max_token_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            add_special_tokens=True,
            return_tensors='pt'
        )

        summary_encoding = self.tokenizer(
            data_row['summary'],
            max_length=self.summary_max_token_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            add_special_tokens=True,
            return_tensors='pt'
        )
        
        labels = summary_encoding['input_ids']
        labels[labels == self.tokenizer.pad_token_id] = -100
        
        return dict(
            input_ids=text_encoding['input_ids'].flatten(),
            attention_mask=text_encoding['attention_mask'].flatten(),
            labels=labels.flatten(),
            decoder_attention_mask=summary_encoding['attention_mask'].flatten()
        )

# %%
class SummaryDataModule(pl.LightningDataModule):
    def __init__(self,train_path,val_path,batch_size=16, text_max_token_len = 2000, summary_max_token_len = 150):
        super().__init__()
        self.train_path,self.val_path= train_path,val_path
        self.batch_size = batch_size
        self.text_max_token_len = text_max_token_len
        self.summary_max_token_len = summary_max_token_len
    
    def setup(self,stage=None):
        train = pd.read_csv(self.train_path)
        val = pd.read_csv(self.val_path)
        self.train_dataset = SummaryDataset(data=train,
                                            text_max_token_len=self.text_max_token_len,
                                            summary_max_token_len=self.summary_max_token_len)
        self.val_dataset = SummaryDataset(data=val,
                                          text_max_token_len=self.text_max_token_len,
                                          summary_max_token_len=self.summary_max_token_len)
    
    def train_dataloader(self):
        return DataLoader(self.train_dataset, shuffle=True, num_workers=4)

    def val_dataloader(self):
        return DataLoader(self.val_dataset, shuffle=False, num_workers=4)

# %%
class T5SumModel(pl.LightningModule):
    def __init__(self, lr=0.0001):
        super().__init__()
        self.lr = lr
        self.model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
    
    def forward(self, input_ids, attention_mask, decoder_attention_mask, labels=None):
        output = self.model(
            input_ids,
            attention_mask=attention_mask,
            labels=labels,
            decoder_attention_mask=decoder_attention_mask
        )
        return output.loss, output.logits
    
    def configure_optimizers(self):
        return optim.AdamW(self.parameters(), lr=self.lr)
    
    def training_step(self, batch, batch_size):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        decoder_attention_mask = batch['decoder_attention_mask']

        loss, outputs = self(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels
        )

        self.log("train_loss", loss, prog_bar=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_size):
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']
        decoder_attention_mask = batch['decoder_attention_mask']

        loss, outputs = self(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels
        )

        self.log("val_loss", loss, prog_bar=True, logger=True)
        return loss

# %%
# Load checkpoint
trained_model = T5SumModel.load_from_checkpoint(
'/kaggle/input/fork-of-t5-fine-tuned-load/lightning_logs/version_0/checkpoints/epoch=2-step=77937.ckpt')
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")

#trained_model.freeze()

def summarizeText(text, mymodel):
    text_encoding = tokenizer(
        text,
        max_length=1000,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    )
    generated_ids = mymodel.generate(
        input_ids=text_encoding['input_ids'],
        attention_mask=text_encoding['attention_mask'],
        max_length=150,
        num_beams=2,
        repetition_penalty=2.5,
        length_penalty=1.0,
        early_stopping=True
    )

    preds = [
            tokenizer.decode(gen_id, skip_special_tokens=True, clean_up_tokenization_spaces=True)
            for gen_id in generated_ids
    ]
    return "".join(preds)
# Out:
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /opt/conda/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:550: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
#train=pd.read_csv('train.csv')
val=pd.read_csv('/kaggle/input/fine-tuning-t5-arabic-summarization-2/val.csv')

# %%
import torch

# Check if CUDA is available and set the device accordingly
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Move the model to the appropriate device
model.to(device)

def summarizeText(text, mymodel):
    # Move input tensors to the same device as the model
    text_encoding = tokenizer(
        text,
        max_length=1000,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        add_special_tokens=True,
        return_tensors='pt'
    ).to(device)

    generated_ids = mymodel.generate(
        input_ids=text_encoding['input_ids'],
        attention_mask=text_encoding['attention_mask'],
        max_length=150,
        num_beams=2,
        repetition_penalty=2.5,
        length_penalty=1.0,
        early_stopping=True
    )

    preds = [
            tokenizer.decode(gen_id, skip_special_tokens=True, clean_up_tokenization_spaces=True)
            for gen_id in generated_ids
    ]
    return "".join(preds)

test = val.sample(10)
for i in range(len(test)):
    sample_row = test.iloc[i]
    text = sample_row['text']
    print('Text : ', text)
    print('\n')
    print('Summary (Ground truth) : ',sample_row['summary'])
    print('\n')
    summary_without_tuning = summarizeText(text, model)
    print("Summary before tuning", summary_without_tuning)
    print('\n')
    summary_with_tuning = summarizeText(text, trained_model.model)  # Use the same model for tuning
    print("Summary after tuning", summary_with_tuning)
    print('\n')
    print('-------------------------------------------------------------------------------------------------')
# Out:
# Text :  لسان الحمل يأتي من نبات له أوراق مسطحة وطويلة ونحيلة وتنمو في كل مكان تقريبا بما في ذلك معظم حدائق المنازل. هناك عدة أنواع منها ولكن جميعها لها عروق عمودية في أوراقها.بعض الناس يعتقدون أنها أعشاب ضارة ولكن لها العديد من الفوائد الطبية. يمكن استخدام النبات على الجرح مباشرة لحمايته وتعزيز عملية الالتئام.ولأوراقها أيضا خواص المضادات الحيوية.  لا يدرك الكثير من الناس أن النبات الموجود في حديقتهم هو لسان الحمل ويرجع ذلك في الأساس إلى وجود طعام آخر يسمى "موز الجنة" وهو فاكهة تشبه الموز، ويحمل كلاهما نفس الاسم العلمي (Plantain). أوراق لسان الحمل هي أعشاب وتختلف عن نبات موز الجنة الذي هو فاكهة.  إن لم تجد عشبة لسان الحمل في مكان حولك فيمكنك طلب أوراق النبات المجففة والأعشاب من بائعي الأعشاب الطبيعية. يمكنك أيضا شراء المراهم والدهانات المصنوعة من لسان الحمل. اقطف عشرة أوراق من لسان الحمل الطازجة. اغل الأوراق بتمهل في 2.5 سم من الماء تقريبا حتى تصبح لينة. خذ الأوراق وقم بهرسها باستخدام ظهر ملعقة ثم اترك العجينة لتبرد.  بعد أن يبرد الخليط أضف بضع قطرات من أي زيت من اختيارك. من الخيارات الجيدة زيت اللوز أو الخروع أو الزيت المعدني. يمكنك استخدام عشبة لسان الحمل المجففة عن طريق خلطها بزيت ثم غلي الأوراق للحصول على عجينة. عندما تنتهي من صنع العجينة ضع طبقة على القشرة. بعدها ضع غطاء من الشاش أو ضمادة عليها. يمكنك تركها كما ترغب. ضعها طوال الليل واغسلها في الصباح أو ضعها واتركها حتى موعد استحمامك. إن كانت قشرة جروح البثور في وجهك فيمكنك وضع العجينة على المنطقة المتضررة من مرتين لأربعة مرات في اليوم. اتركها لمدة عشر إلى خمس عشرة دقيقة ثم اشطف العجينة بالماء الدافئ؛ ربت على وجهك حتى يجف.
#
#
# Summary (Ground truth) :  جد بعض أوراق لسان الحمل. اصنع عجينة من الأوراق الطازجة. ضع العجينة على قشرة الجرح. استخدم العجينة على وجهك.
#
#
# Summary before tuning لا يزال الكثير من الناس يعتقدون أن النبات الموجود في حديقتهم هو لسان الحمل.
#
#
# Summary after tuning اعرف أنواع لسان الحمل. جرب أوراق نبات موز الجنة. صنع عجينة من الزيت. استخدم العجينة على وجهك.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  الأفراد الذين يحاولون الانتحار عادة ما يعانون من حالات مرض نفسية بالغة، مثل: الاكتئاب، ويمكنهم الحصول على المساعدة من أجل علاج ذلك.  إذا كانت الميول الانتحارية لديك ناتجة عن حدث معين، مثل: الحزن الناتج عن الهجر، أو فقدان الوظيفة، أو التعرض للإعاقة؛ فعليك أن تدرك أنه حتى هذا النوع من المواقف الاكتئابية يمكن أن يتم التغلب عليها عن طريق تلقى المساعدة العلاجية المناسبة. بالنسبة للأفراد أصحاب الإيمان الديني، ومن تقدر الجوانب الروحية على التأثير فيهم، فإن الحديث مع رجال الدين قد يكون وسيلة رائعة من أجل التعامل مع هذه الحالة.  بالنسبة للبعض، يكون التعامل الديني والروحي مع الأزمة، أكثر فائدة وقابلية للتأثير عليهم من الحديث مع الأفراد المختصين في علم النفس. عادة ما يكون لدى رجل الدين الذكي والعالم القدرة على مساعدة الأفراد وقت أزماتهم الكبرى، بما فيها مواقف اليأس التي قد تقود للانتحار.  رجل الدين قادر على مساعدتك على التخفيف من آلامك، عن طريق ما يقدمه لك من رؤية روحية مختلفة لما يخص التعامل مع الابتلاءات والأزمات في الحياة، كما أنه يقدم لك بعض الأفكار التي سوف يكون من الجيد بالنسبة لك أن تعيد النظر بها. يوجد مجموعات دعم، عبر الإنترنت أو في المجتمع المحلي، يمكنك أن تتحدث فيها عن ميولك الانتحارية، وأن تجد الدعم من الأفراد الذين يمرون بنفس الوضعية، أو من سبق لهم محاولة تنفيذ الأمر، بهدف مشاركة مشاعركم وخبراتكم من جهة، والعمل على تشكيل سلوكيات مضادة لهذه الأفكار من جهة أخرى؛ من أجلتجنب الميل القهري للقيام بالانتحار.  يمكن أن تسأل طبيبك النفسي من أجل اقتراح مجموعة دعم يمكنك المشاركة بها، أو أي معلومات عن لقاءات المجموعات الشبيهة. يمكنك البحث عبر الإنترنت كذلك عن مجموعات الدعم في مجتمعك المحلي المحيط. أهم شيء عليك دائما أن تتذكره هو أنه مهما كان سبب مرورك بهذه الوضعية، فأنت لست وحيدا. عليك أن تتواصل مع الأفراد الموجودين حولك من أجلك، والقادرين على استيعاب وفهم ما تشعر به، والراغبين حقا في تقديم المساعدة. إذا كنت تبحث عن مكان جيد للبدء به، فحاول أن تتواصل مع أحد هذه الخدمات:    الخط الساخن القومي للوقاية من الانتحار. الخدمات الخاصة بالأفراد أصحاب الاضطرابات الجنسية ومشاكل الاغتراب وعدم التقبل من المجتمع. الخدمة الخاصة بمتابعة المحاربين القدامى الذين يعانون من الأثار النفسية الناتجة عن الحروب. خدمات دعم المراهقين، أو حالات التعامل مع العنف الأسري، ووقاية الشباب من الانتحار. قم بإرسال بريد إلكتروني مجهول الهوية إلى أي جهة خيرية تقدم خدمات المساعدة النفسية والوقاية من الانتحار. تواصل مع معالج نفسي. ابحث في دليل الهاتف عن قائمة الأطباء النفسيين في منطقتك المحلية التي تعيش بها، أو يمكنك أن تجري بحثا عبر الإنترنت. أخبر صديقك بما تشعر به، وبأنك بحاجة لمساعدته في الحال. اطلب منه أن يعيد تذكيرك بالأشياء الجيدة في حياتك وصفاتك الشخصية المميزة ونقاط قوتك، أو تحدث معه حول الأوقات الممتعة التي عشتوها سويا.   اختر صديقا تؤمن بأنه جدير بالثقة. الحديث في هذا الوقت مع صديق غير وفي عن الوضعية التي تمر بها، قد يجعل الوضع أسوأ وأسوأ، حيث أن هذا النوع من الأصدقاء لن يقدم لك ما تحتاجه من دعم، وسيتكاسل عن التواجد بجانبك. تجنب الوحدة. تأكد من أن أصدقائك وعائلتك لا يتركونك بعيدا عن نظرهم. إذا كان لا يوجد أي شخص يمكنه أن يراقبك ويتواجد معك، فعليك أن تقوم بوضع نفسك في واحدة من غرف الطوارئ في المستشفيات من أجل التأكيد على أنك لست وحيدا. إذا كنت جزءا من مجموعة دعم متعلقة بهذا الأمر، فاستند على بقية افراد المجموعة من أجل نيل الدعم الإضافي من أفراد قادرين حقا على فهم واستيعاب ما تمر به، ويعرفون كيفية تقديم المساعدة التي تحتاج لها.
#
#
# Summary (Ground truth) :  طلب المساعدة من أخصائي رعاية للصحة العقلية. تحدث مع رجل دين. المشاركة في مجموعات الدعم. اطلب المساعدة من الأفراد المتفهمين والواعيين بكيفية التعامل مع هذه الميول الانتحارية. اتصل بصديق.
#
#
# Summary before tuning يمكن أن تشعر بأنك تعاني من ميولك الانتحارية، إذا كنت ترغب في التعامل مع هذه الوضعية.
#
#
# Summary after tuning تعرف على مسببات الميول الانتحارية. تحدث مع رجل الدين. انضم إلى مجموعة دعم. ابحث عن خدمات المساعدة النفسية ووقاية الشباب من الإناث الحادة.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  بينما يصعب عليك تقبل ذلك، لكن لعلك تقوم بفعل شيء ما يجعله ينبذك. حاول أن تفكر في وجهة نظره لترى إذا ما كان هناك أي تصرف سيء من قبلك.  غالبا ما تشغل الغيرة الكراهية. قد يراك زميلك في العمل أكثر نجاحا منه أو يجد فيك من السمات ما ينقصه. حتى لو لم يكن في استطاعتك بالضرورة إيقاف غيرته، فكر فيما إذا كنت تتبجح وتتعجرف بخصوص نجاحك. إن كنت تفعل، فقد يكون هذا ما يثير كراهيته.  قد يخلط الناس بين الخجل والوقاحة. إذا كنت لا تتواصل مع زميل عملك كثيرا، فقد يظنك باردا. حاول أن تعامله بود أكثر.  هل يبدو أن الآخرين في العمل يحبونك؟ إن كان لا يحدث، فقد تكون منخرطا في سلوك معين دون قصد ينفر الآخرون منك. حاول التحدث مع زميل عمل مقرب واسأله عن انطباع موضوعي عن سلوكك. راجع بحرص أي تعاملات سابقة قمت بها مع زميلك هذا. أحيانا ما ينبذ الناس غيرهم إثر تعامل واحد سيء. لعلك قلت أو فعلت شيئا أغضبه.  قد يكون أمرا بسيطا، مثل عدم انتظاره قبل ركوب المصعد أو لعلك قلت شيئا يحمل قدرا من الوقاحة، كتعليق على ملبسه لم يستقبله زميلك برحابة صدر.  لو تمكنت من تحديد أي أخطاء ارتكبتها في حقه، اعتذر لزميلك فورا. لو كان غضبه منك قد نبع من سوء فهم، ستتمكن إذا من توضيح الأمور بنقاش سريع. كن صادقا مع نفسك بخصوص مدى انزعاجك من الموقف. لو لم تكن قادرا على فصل حياتك العملية عن الشخصية، قد يكون الآن هو الوقت المناسب للبحث عن وظيفة جديدة. لكن اعلم مع ذلك أنك ستجد أناسا مثله في جميع المهن. لو كان الزملاء غير المحتملين قادرين فعلا على إغضابك، قد تكون بحاجة لاستشارة أخصائي نفسي.
#
#
# Summary (Ground truth) :  ضع وجهة نظر زميلك في اعتبارك. راجع تعاملاتك السابقة مع زميلك. قيم معدل توترك.
#
#
# Summary before tuning هل يمكن أن تكون متمسكة بالآخرين في عملك؟
#
#
# Summary after tuning فكر في الموقف. تواصل مع زميل في العمل. لا تهتم بالآخرين. اعلم متى يجب عليك أن تبحث عن وظيفة.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  اترك قدمك اليمنى في موضعها وقم بتحميل وزنك على قدمك بالخلف (القدم اليسرى). هذه هي العدة ١. هذه هي العدة ٢ في خطوة الروك. هذه هي العدة ٣، أو العدة الأولى من الخطوة ثلاثية الحركة ناحية اليسار. هذه هي العدة "أ" ، أو العدة الثانية من الخطوة ثلاثية الحركة. هذه هي العدة ٤، أو الحركة الثالثة من الخطوة الثلاثية. هذه هي العدة ٥. هذه هي العدة "أ". هذه هي العدة ٦، أو العدة الأخيرة في الرقصة. تذكر اتباع هذه العدات ١-٢-٣-٤-أ، ٥-أ-٦.
#
#
# Summary (Ground truth) :  اخط للخلف بقدمك اليسرى لتقوم بالحركة الأولى في خطوة الروك. ارفع قدمك اليمنى ثم إنزلها مرة أخرى. تحرك جانبا باستخدام قدمك اليسرى. قم بتحريك قدمك اليمنى لتقابل قدمك اليسرى. تحرك جانبا باستخدام قدمك اليسرى. قم بتحميل وزنك على القدم اليمنى. تحرك جانبا باستخدام قدمك اليسرى. تحرك ناحية اليمين باستخدام قدمك اليمنى. قم بتكرار خطوة الروك والخطوة الثلاثية مجددا، متحركا من اليسار لليمين.
#
#
# Summary before tuning هذه هي العدة. اترك قدمك اليمنى في موضعها وتحميل وزنك بالخلف.
#
#
# Summary after tuning ابدأ بقدمك اليمنى. اكتب العدة ١. أمسك بالعدة ٢. أو الآن تدرب على الروك.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  هذه هي أول خطوة لتنظيف المرتبة والتي تزيل من خلالها عث الغبار والأتربة والجلد الميت والشعر وأي شيء عالق بالمرتبة. صل رأس المكنسة بفوهة الفرشاة الواسعة عند تنظيف سطح المرتبة واستعمل الرأس الخاصة بالأثاث المنجد للوصول للفتحات الصغيرة وتنظيف الحواف والأجزاء الطويلة الغائرة والجوانب والزوايا. تأكد أن تكون فتحة الفوهة والفرشاة اللتين تصلهما برأس المكنسة نظيفين تماما قبل استعمالهما للتنظيف. يجب أن تنظف على الفور أي سوائل لا زالت تبلل المرتبة. أحضر قطعة قماش نظيفة مبللة بماء بارد واستعملها لامتصاص السائل المسكوب على المرتبة؛ لا تفرك البقعة أو تدعكها لأن هذا قد يجعلها تتغلغل في المرتبة لمكان أعمق واستمر باستعمال القماش لامتصاص السائل حتى تزيله كله من عليها. ضع ملعقتين كبيرتين (30 ملل) من الماء الأكسجيني مع ملعقة كبيرة (15 ملل) سائل غسيل صحون في طبق، وقلبهم بالملعقة حتى يختلطان وتتكون رغوة. بلل فرشاة أسنان قديمة بالرغوة واستعملها لفرك المنطقة المبللة من المرتبة. بعد ذلك أزل بقايا المنظفات من على سطح المرتبة باستخدام قماشة نظيفة رطبة.  بالنسبة للمراتب الرغوية، استعمل معها أقل كمية ممكنة من المنظف لأن هذه المراتب يجب ألا تبتل نهائيا. هذا المحلول مفيد لتنظيف بقع الأوساخ والأطعمة والمشروبات. قم برش منظف إنزيمي من بخاخ على قماشة نظيفة ثم استعملها لتشرب البقعة من المرتبة. اترك المنظف الإنزيمي على المرتبة لقرابة 15 دقيقة ثم جفف المنطقة المبقعة بنفس القماشة لكي تزيل البقعة منها؛ بعد ذلك استعمل قماشة نظيفة مبللة بماء بارد لتجفيف المنطقة من السائل الإنزيمي.  لا ترش منظفات سائلة على المرتبة مباشرة. المراتب ليست مصممة بصورة تسمح بأن تبتل – خاصة المراتب الرغوية – لذا استعمل أقل قدر ممكن من المنظفات تحتاجه لتنظيف البقع. المنظفات الإنزيمية تفكك بروتينات الدم والبول والعرق والقيء وغيرها من البقع الحيوية، وهي مفيدة أيضا لتنظيف بقع الدهون والزيوت. بعد إزالة البقع من المرتبة، يمكنك تنظيفها وإزالة الروائح السيئة منها؛ ستقوم بهذا من خلال إضافة كمية وفيرة من صودا الخبز على سطح المرتبة بالكامل.  لتعطي المرتبة رائحة منعشة، قلب 5 قطرات من الزيت العطري المفضل لديك على صودا الخبز قبل أن ترشها على المرتبة. إذا أردت طريقة لتوزيع صودا الخبز على المرتبة بالتساوي، ضعها أولا في منخل (غربال) ثم وزعها على سطح المرتبة باستخدامه. اتركها على المرتبة لثلاثين دقيقة على الأقل، وسوف يتيح هذا الوقت لها أن تحلل الأحماض وتمتص الروائح وأي سوائل باقية من تنظيفك للبقع. يمكنك ترك صودا الخبز لساعات إذا كان وقتك يسمح بهذا. كلما طالت مدة بقائها على المرتبة، زادت كفاءتها في الامتصاص والتنظيف. بعد أن تترك صودا الخبز تعمل على تنظيف المرتبة، سوف تحتاج لتنظيف المرتبة من صودا الخبز نفسها عن طريق استعمال مكنسة كهربائية. سوف تسحب صودا الخبز بالمكنسة الكهربائية مع كل الأحماض والروائح والسوائل التي امتصتها. استعمل الفرشاة لتلامس سطح المرتبة، واستعمل الفوهة الطويلة للوصول للشقوق والزوايا وما بين الطبقات والأجزاء الغائرة. بعد أن تنظف المرتبة، سيكون من المفيد أن تتركها مكشوفة لبعض الوقت كي تجف أي سوائل متبقية بها. الرطوبة المحتجزة داخل المرتبة يمكن أن تؤدي إلى تكون العفن الذي تصعب إزالته جدا.  افتح شباك الغرفة إن لم يكن الجو باردا جدا بالخارج كي تسمح للهواء النقي بدخول الغرفة وتجفيف المرتبة أسرع. يمكنك كذلك أن ترفع أغطية الشبابيك الزجاجية وتفتح الستائر كي تدخل أشعة الشمس للمكان، لأن الأشعة فوق البنفسجية في الشمس تساعد في قتل البكتيريا والعفن من المرتبة وتخلصها من الروائح بدرجة أكبر وتجعلها تجف أسرع.
#
#
# Summary (Ground truth) :  نظف المرتبة بالمكنسة الكهربائية. نظف أي سوائل مسكوبة حديثا. حدد البقع النظيفة. نظف البقع الحيوية باستخدام منظف إنزيمي. قم برش صودا الخبز على المرتبة. دع صودا الخبز تأخذ وقتها لامتصاص الروائح. نظف المرتبة بالمكنسة الكهربائية ثانية. اجعل المرتبة تتعرض للتهوية.
#
#
# Summary before tuning يمكن أن تكون المرتبة أكثر شيوعا في العالم، ولكن هل ترغب في تنظيفها من خلال استخدام مكنسة كهربائية؟
#
#
# Summary after tuning قم بتنظيف المنطقة بالمكنسة الكهربائية. استعمل الماء الأكسجيني مع سائل غسيل الصحون. نظف بقع الأوساخ باستخدام منظف إنزيمي. اترك المرتبة تنظيف البقع من خلال صودا الخبز.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  تبدأ الخطوة الأولى في الانتقال للعناية الطبيعية بشعرك بالتوقف عن الفرد أو العلاج الكيميائي. يسمح هذا لشعرك بالبدء في النمو بملمسه الطبيعي، ولكن شعرك الذي قمت بفرده كيميائيا سيبقى مفرودا للأبد. أسهل طريقة للانتقال إلي العناية الطبيعية بشعرك تكون بقص كل الشعر المفرود كيميائيا. يجنبك ذلك التعرض للتحول المفاجئ في ملمس شعرك، بين ذاك المفرود كيميائيا والذي ينمو طبيعيا. على الرغم من ذلك، فقص جزء كبير من شعرك هو بمثابة تضحية كبيرة بطوله، ومن ثم ستضطرين للتأقلم والتعامل مع شعرك القصير.   قص شعرك في المرحلة التي يتصل بها شعرك الطبيعي بالشعر المفرود هي أسلم طريقة للتحول إلى العناية الطبيعية بشعرك، لأن شعرك سيصبح معرضا للتكسير والتقصيف إذا لم تتخلصي من هذا الشعر المفرود. لا توجد طريقة لإعادة الشعر المفرود كيميائيا إلى سابق عهده. الشعر الذي ينمو جديدا من الجذور هو شعرك الطبيعي ولكن الآخر المفرود سيظل مفرودا للأبد. إذا كنت تريدين أن تعتني بشعرك وتتركيه ينمو طبيعيا ولكن لا يمكنك التضحية بطوله، يمكنك أن ترتدي وصلات الشعر بينما تنتظرين نموه. ستخفي الوصلات التباين الجذري في ملمس شعرك وستعطيك الشعر الطويل الذي تصبين إليه. عندما يصل شعرك الطبيعي إلى الطول المرغوب فيه، يمكنك التخلي عن الوصلة. قصي الشعر المفرود، وحافظي على نمو شعرك الطبيعي.  ثبتي وصلة الشعر بواسطة الخياطة بدلا من اللصق، لأن لصق الوصلات ينزع من الرأس بقوة عند فصله. لتخفيف التحول الحادث في شعرك بين المفرود والطبيعي، يمكنك عمل ضفائر صفوف الذرة، أو أي إطلالات  أخرى تحميه حتى ينمو بالطول الكافي الذي يجعلك راضية عن قص الشعر المفرود. تمتاز هذه التصفيفات بحاجتها للقليل من العناية مع الحفاظ على طول شعرك.  يمكنك أيضا تصفيف شعرك بإطلالات تناسب الشعر الأجعد، مثل: عقد البانتو (بالإنجليزية: Bantu knots) وتمويج شعرك. تخفي هذه الإطلالات حقيقة أن شعرك في مرحلة الانتقال.
#
#
# Summary (Ground truth) :  توقفي عن العلاج الكيميائي. قصي شعرك. ارتدي وصلات الشعر خلال عملية الانتقال. صففي شعرك بطرق تحميه خلال عملية الانتقال.
#
#
# Summary before tuning يمكن أن تتخلص من الشعر المفرود كيميائيا إلى سابق عهده.
#
#
# Summary after tuning قصي كل الشعر المفرود كيميائيا. ضعي وصلات شعرك بينما تنتظرين نموه. صففي شعرتك بإطلالة تناسب مناسبة.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  يتم تحضير الزيت العطري من كمية صغيرة من زيت أساسي مضاف على زيت ناقل، ويمكن أن يحضر كذلك من خلال إضافة نوع زيت أساسي مع ناقل صناعي. تعرف المركبات العطرية الصناعية المضافة لناقل طبيعي أو صناعي باسم الزيوت العطرية.  الزيوت الأساسية هي زيوت ناتجة عن عملية طبيعية تحضر بواسطة عملية التقطير. استخداماتها متنوعة، لكنها بشكل عام أقوى بكثير ونادرا ما تستخدم من غير أن تخفف. الاستخدام الرئيسي للزيوت العطرية هو تعطير الجو. تسمى الزيوت العطرية أيضا بزيوت العطر. للزيوت العطرية نطاق أكبر من الروائح لأنها غالبا ما تحضر بطرق صناعية، وتكلفتها عادة أقل بكثير من الزيوت الأساسية. كذلك غالبا ما تكون رائحتها أقوى وتدوم لفترة أطول من رائحة الزيوت الأساسية.  يعد استخدام زيوت العطر أكثر استدامة للبيئة من استخدام الزيوت الأساسية. على سبيل المثال: زيت خشب الصندل (زيت أساسي) هو نتاج قتل الشجرة بأكملها. يتوقف قرار الاختيار بين استخدام الزيوت العطرية أو الزيوت الأساسية على غرضك، فلكل نوع مزاياه. يمكن أن تسبب بعض الزيوت الأساسية استجابات سلبية عند ملامستها للجلد، أما الزيوت العطرية تكون مصنعة بطريقة تجعلها تتيح الوصول لرائحة الزيت العطري عن طريق تخفيفه باستخدام ناقل طبيعي أو صناعي وبالتالي يقل احتمال حدوث ردود الفعل التحسسية. رائحة الزيوت العطرية جميلة، لكن ليس لها قيمة علاجية حقيقية. تحتوي الزيوت الأساسية على المستخلص الحقيقي للزهور والأعشاب والجذور والصمغ، ولا تكون مخففة بأي نوع من الزيوت الناقلة على عكس الزيوت العطرية.  تحسن الزيوت العطرية الروح المعنوية ببساطة بمجرد توفيرها لرائحة جيدة. تختلف كثافة نفس النوع من الزيوت الأساسية لأنه يقطر على دفعات صغيرة في مناطق محلية مختلفة. لهذا قد يجد المصنعون الذين يحاولون الوصول إلى منتج ثابت صعوبة في هذا الأمر، ولهذا يستعيض بعضهم بالزيوت العطرية عن الزيوت الأساسية عندما يكون هذا ممكنا للوصول إلى درجة أكبر من الاتساق تتيح للمشتري التنبؤ بالمنتج.
#
#
# Summary (Ground truth) :  من المهم أن تفرق بين الزيوت العطرية والزيوت الأساسية. افهم فوائد استخدام زيوت العطر. استخدم الزيوت الأساسية في العلاج العطري.
#
#
# Summary before tuning يستخدم الزيت العطر في جميع أنحاء العالم، لكنه ليس لها قيمة علاجية حقيقية.
#
#
# Summary after tuning حدد نوع الزيت العطري. تعرف على الزيوت العطرية. افهم ما يجعلك تشعر بالارتياح.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  تستهلك الغسالات قديمة الطراز (التي يتم وضع الملابس فيها من الأعلى) كميات أكبر من المياه (ما بين 150 إلى 170 لتر في المرة) لكنك قادر على تقليل ذلك للنصف تقريبا عن طريق استخدام غسالات الملابس عالية الكفاءة، سواء كانت علوية أم أمامية الباب. تمتاز الغسالات عالية الكفاءة، بالإضافة لتوفيرها للمياه بالطبع، لقدرتها على تنظيف الملابس بجودة أفضل.  تستهلك الغسالات أمامية الباب كمية مياه وطاقة كهربية أقل من الغسالات علوية الباب. على أي حال، احرص على إجراء عملية بحث دقيقة بشكل مسبق لضمان أنك تختار الغسالة التي تحقق لك أفضل استفادة ممكنة. لا تقذف القليل من الجوارب وقميصين وتقوم بتشغيل الغسالة في الحال. في المقابل، تأكد من ملء الغسالة بالحمولة الكاملة، وهو ما يضمن ألا تهدر المياه أثناء تشغيل الغسالة.   نؤكد من جديد على أهمية ملء الغسالة بحمولتها الكاملة، دون نقص ولكن أيضا دون زيادة. يتسبب وضعك لكميات كبيرة من المياه، أكبر من الحمولة المحددة للغسالة، في إلحاق الضرر بالغسالة من جهة، ومن جهة أخرى لن تتم عملية تنظيف الملابس بشكل صحيح.   استخدم الوضعية الاقتصادية المتاحة في برامج الغسل لتنظيف ملابسك؛ يوفر لك ذلك كلا من المياه والكهرباء على حد سواء. تحتاج الغسالة إلى المياه من أجل توليد الطاقة، والطاقة مطلوبة بدورها من أجل تسخين المياه! لكنك عن طريق الاعتماد على برنامج غسل الملابس بالمياه الباردة تنجح في توفير كلا من المياه والطاقة. تضمن لكن المياه الباردة كذلك في التخلص من البقع ومنع ألوان الملابس من الاختلاط. قد لا تقدر على تنفيذ هذه الخطوة مع كل ملابسك، لكن على الأقل احرص على تعليق أكبر عدد ممكن من القمصان والفساتين والبناطيل وغيرهم من الملابس على حمالات التجفيف. أحبال الغسيل بدورها شائعة للغاية في غالبية المنازل. لا تشعر بإغراء الاعتماد على تجفيف الملابس السهل عن طريق مجفف الغسالة، والذي يستهلك الكثير من الطاقة، التي تحتاج بدورها إلى إهدار الكثير من المياه لتوليدها. لا تحتاج العديد من قطع الملابس مثل الجينز والسترات إلى الغسيل بعد كل مرة ترتديها. تأكد أن قطع الملابس التي تقوم بغسلها متسخة بالفعل ولن يمكنك ارتدائها أبدا إلى بعد الغسل. لن يوفر لك ذلك المياه فقط، ولكنه أيضا يحمي الملابس من فقدان رونقها بسبب كثرة الغسيل.   من الطبيعي للغاية أن ترتدي البيجاما مرتين أو ثلاثة قبل أن تفكر في غسلها، خاصة إذا كنت تحرص على الاستحمام قبل الذهاب للنوم. تحتاجين لتغيير ملابسك الداخلية وجواربك بشكل يومي، لكن الأمر مختلف مع السراويل والجينز والتنانير التي يمكنك ارتدائها أكثر من مرة بين كل غسلة وأخرى. إذا كنت ترتدي سترتك أو البلوزة أو السويت شيرت الرجالي فوق قميص أو بلوزة داخلية، فلن تحتاج إلا إلى غسل قطعة الملابس الأقرب للجسد. قم بتعليق الفوط والمناشف على حمالة التجفيف بعد كل استحمام وأعد استخدامهم عدة مرات قبل أن تضعهم في كومة الغسيل.
#
#
# Summary (Ground truth) :  استبدل غسالة الملابس الحالية بواحدة عالية الكفاءة. تأكد أنك تشغل الغسالة على حمولة كاملة. استخدم المياه الباردة بدلا من المياه الساخنة. قم بتجفيف ملابسك على حمالة التجفيف أو أحبال الغسيل. قلل عدد مرات الغسيل.
#
#
# Summary before tuning يمكن أن تكون من بين أكثر الأمور صعوبة في التخلص من البقع، وذلك باستخدام الغسالات.
#
#
# Summary after tuning استخدم غسالة الملابس عالية الكفاءة. قم بإجراء عملية بحث دقيقة. تأكد من ملء الغسالة بحمولتها الكاملة. لا تستخدم مجفف الغسيل إلا بعد كل استحمام.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  الهدف هنا بسيط للغاية، فكل لاعب عليه إنقاص نقاطه حتى يصل لصفر.  لم سميت ب "01" إذا؟ يشير هذا إلى أن كل لاعب يبدأ اللعبة بمجموع نقاط ينتهي ب "01"، حيث تبدأ الألعاب الفردية بشكل عام وكل لاعب لديه 301 أو 501 نقطة مثلا، أما في ألعاب الفرق الكبيرة يبدأ المجموع من 1001. الأوكي هو الخط الذي يجب على الرامي الوقوف ورائه، ويقع على بعد 2.37 متر من وجه اللوحة. من يصل سهمه لأقرب مكان من "الدبل بول" أو "الهدف المزدوج" يبدأ أولا. يتم طرح النقاط التي أحرزها اللاعب من مجموعه الذي بدأ به.  على سبيل المثال، إذا بدأ لاعب بمجموع 301 نقطة وأصاب 54 نقطة فإن مجموعه الكلي يصبح 247. يرجع هذا إلى طريقة الفوز في اللعبة، فلكي تفز أو تحرز "كلوز أوت" كما يقال يجب أن تصل إلى صفر بالضبط، بالإضافة إلى أن النقاط التي توصلك للصفر يجب أن تكون مزدوجة.   على سبيل المثال إذا تبقى لدي اللاعب نقطتين فقط فيجب أن يحرز 1 مزدوج، أما إذا كان تبقى 18 فيجب إحراز 9 مزدوجة. إذا كان الازدواج مستحيلا كمن تبقى لديه 19 نقطة مثلا فيجب على اللاعب إحراز 3 منفردة أولا ليصل إلى 16، وبعدها يحرز 8 مزدوجة للفوز.
#
#
# Summary (Ground truth) :  اعلم أن أشهر صورة للعبة تعرف ب "01". حدد "الأوكي". ارم سهما لتحديد من يبدأ أولا. تبادلوا الأدوار برمي 3 أسهم كل دور. ما أن يقترب كل لاعب من الصفر فيجب الحرص على إصابة المناطق المطلوبة فقط.
#
#
# Summary before tuning يلعب لاعب الفرق الكبيرة في الألعاب الأولمبية، ولكن هل هناك طريقة للفوز في اللعبة؟
#
#
# Summary after tuning تعرف على هدف اللاعب. ابحث عن مكان "الأوكي" في اللوحة. تأكد من أن النقاط التي يبدأ بها لاعب هو الأول فقط. تحرز أو احرز كلوز أو ت.
#
#
# -------------------------------------------------------------------------------------------------
# Text :  يصعب في الحقيقة التعامل مع سائل واحد نقي، فعادة ما نتعامل مع سوائل تتكون من خليط من مواد مختلفة. يصنع أكثر هذه الخلائط شيوعا عن طريق إذابة مادة كيميائية "المذاب" في كمية كبيرة من مادة أخرى "المذيب"، وسيفيد في هذه الحالة معرفة معادلة تسمى بقانون رولت (المسماة باسم الفيزيائي فرانسوا ماري رولت) ، والتي تبدو هكذا: Pمحلول=PمذيبXمذيب. تشير المتغيرات في هذه المعادلة إلى:   "Pالمحلول :" ضغط البخار للمحلول ككل (مجموع كل أجزائه المكونة) " Pمذيب :" ضغط البخار للمذيب. " Xمذيب:" الجزء المولي للمذيب. لا تقلق إذا لم تكن تعرف مصطلحات مثل "الجزء المولي"، فسنشرحها في الخطوات القليلة التالية. تحتاج لمعرفة المواد التي تتعامل معها قبل أن تستطيع حساب ضغط البخار لسائل مختلط. تذكر أن المحلول يتكون من إذابة المذيب في المذاب، وأن المادة التي تذوب هي المذاب بينما المادة التي تذيبها هي المذيب.   دعنا نحل مثالا بسيطا في هذا الجزء لتوضيح المفاهيم التي نتحدث عنها. لنفترض أننا نريد معرفة ضغط البخار لشراب السكر. يتكون شراب السكر تقليديا من جزء من السكر مذاب في جزء من الماء، لذلك سيكون الماء هو المذيب بينما السكر هو المذاب.   لاحظ أن الصيغة الكيميائية للسكروز (سكر الطاولة) هي C12H22O11. سيصبح هذا مهما قريبا. تؤثر حرارة السائل في ضغطه البخاري كما رأينا في معادلة كلاوزيوس وكلابيرون، فسيزيد ضغط البخار للسائل عموما كلما زادت حرارته حيث سيتبخر مزيد من السائل مع زيادة الحرارة مؤديا إلى زيادة ضغط البخار في الوعاء.  لنفترض أن درجة حرارة شراب السكر في مثالنا هي 298 كلفن (حوالي 25 س). يوجد الضغط الكيميائي لكثير من المواد والمركبات الشائعة في مراجع الكيمياء، ولكن تكون هذه القيم عادة للمواد في حرارة 25 س/298 كلفن أو عند درجة الغليان. يمكنك أن تستخدم هذه القيم المرجعية إذا كان محلولك عند إحدى درجات الحرارة هذه، ولكنك ستحتاج لإيجاد ضغط البخار بنفسك إذا كانت درجة الحرارة مختلفة.   ستساعدك معادلة كلاوزيوس وكلابيرون هنا. استخدم القيمة المرجعية للضغط البخار و298 كلفن (25 س) كقيم ل P1 وT1 بالترتيب. يمكننا استخدام جداول قيم ضغط البخار المرجعية في مثالنا حيث درجة حرارة الخليط هي 25 س. سنجد أن ضغط البخار للماء عند 25 س هو 23.8 ملم زئبق. آخر ما سنحتاج قبل أن نتمكن من الحل هو الجزء المولي للمذيب. يسهل إيجاد الجزء المولي بتحويل مكونات المحلول للمول لمعرفة النسبة المئوية التي يشغلها كل مكون من عدد المولات الكلي أي أن الجزء المولي لكل مكون سيساوي (عدد مولات المكون)/(عدد المولات الكلي للمحلول).   لنفترض أنه يوجد في شراب السكر لتر من الماء ولتر من السكروز (السكر). سنحتاج الآن لمعرفة عدد مولات كل واحد منهما، وذلك عن طريق إيجاد كتلة كل واحد منهما ثم إلى استخدام الكتلة المولية للتحويل لمول. كتلة لتر من الماء تساوي 1000 جم. كتلة لتر من السكر تساوي 1056.7 جم تقريبا.   عدد مولات الماء: 1000 جم × 1 مول / 18.05 جم = 55.51 مول. عدد مولات السكروز: 1056.7 جم × 1 مول / 342.2965 جم = 3.08 مول (لاحظ أنه يمكنك إيجاد الكتلة المولية للسكروزمن صيغته الكيميائية C12H22O11). العدد الكلي للمولات: 55.51 + 3.08 = 58.59 مول. الجزء المولي للماء: 55.51/58.59 = "0.947" وجدنا الآن كل ما نحتاج لحل معادلة قانون رولت، وهذا الجزء سهل جدا: أدخل فقط قيم المتغيرات في معادلة قانون رولت المبسطة المذكورة في بداية هذ الجزء(Pمحلول = PمذيبXمذيب).  سنحصل بإدخال قيمنا على: Pمحلول= (23.8 ملم زئبق)(0.947) Pمحلول = 22.54 ملم زئبق، وهذا منطقي حيث أنه يوجد فقط قليل من السكر ذائب في كثير من الماء (برغم أن المكونين في الحقيقة لهما نفس الحجم)، وبالتالي سيقل ضغط البخار بقدر قليل.
#
#
# Summary (Ground truth) :  اكتب قانون رولت. تعرف على المذيب والمذاب في المحلول. جد حرارة المحلول. أوجد ضغط البخار للمذيب. أوجد الجزء المولي للمذيب. حل.
#
#
# Summary before tuning كيف يمكنك التعامل مع سائل واحد نقي؟ الصحفي العلمي ديفيد روبسون يبحث في هذا الأمر.
#
#
# Summary after tuning تعلم معادلة تسمى ب قانون رولت. اكتب مصطلحات عن "جزء المولي للمذيب". جد ضغط البخار لشراب السكر. احسب حرارة الوعاء. حلل الجزء الأكثر مروعا.
#
#
# -------------------------------------------------------------------------------------------------

# %%
test = val.sample(100)
sum_results=[[]]
for i in range(len(test)):
    sample_row = test.iloc[i]
    text = sample_row['text']
    summary_with_tuning = summarizeText(text, trained_model.model) 
    sum_results.append(summary_with_tuning)

# %%
from rouge_score import rouge_scorer

# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Initialize lists to store individual ROUGE scores
rouge1_scores = []
rouge2_scores = []
rougeL_scores = []

# Iterate through test samples and corresponding summaries
for i in range(len(test)):
    sample_row = test.iloc[i]
    text = sample_row['text']
    summary_with_tuning = summarizeText(text, trained_model.model)
    
    summary = sample_row['summary']

    # Compute ROUGE scores for each sample
    scores = scorer.score(summary, summary_with_tuning)
    
    # Store individual ROUGE scores
    rouge1_scores.append(scores['rouge1'].fmeasure)
    rouge2_scores.append(scores['rouge2'].fmeasure)
    rougeL_scores.append(scores['rougeL'].fmeasure)

# Compute average ROUGE scores
avg_rouge1 = sum(rouge1_scores) / len(rouge1_scores)
avg_rouge2 = sum(rouge2_scores) / len(rouge2_scores)
avg_rougeL = sum(rougeL_scores) / len(rougeL_scores)

print("Average ROUGE-1 F1 Score:", avg_rouge1)
print("Average ROUGE-2 F1 Score:", avg_rouge2)
print("Average ROUGE-L F1 Score:", avg_rougeL)
# Out:
# Average ROUGE-1 F1 Score: 0.027266899766899767
# Average ROUGE-2 F1 Score: 0.004318181818181817
# Average ROUGE-L F1 Score: 0.027266899766899767
